# %% [markdown]
# <a href="https://colab.research.google.com/github/Susanna-Salata/goit-DS/blob/main/GoIT_DS_HomeWork_3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Третья часть
#
# В таблице приведены данные о взаимонезависимых доходностях трех акций: A, B, C.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Постройте линии регрессии, с помощью функции regplot, зависимости доходности одной акции от другой. Всего три графика. Выберите пару акций которые наименее зависимы в доходностях от друг друга.

# %%
import seaborn as sns
import pandas as pd

# %%
data =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/HW_3_3.csv', sep="\t")
data
# Out:
#    Момент наблюдения  Доходность A, %  Доходность B, %  Доходность C, %
# 0                  1               25                0               10
# 1                  2              -10               15               25
# 2                  3               10               -5              -15
# 3                  4                5                5               -5
# 4                  5               35               20               -5
# 5                  6               13               25               15

# %%
sns.regplot(x='Доходность A, %', y='Доходность B, %', data=data)

# %%
sns.regplot(x='Доходность A, %', y='Доходность C, %', data=data)

# %%
sns.regplot(x='Доходность B, %', y='Доходность C, %', data=data)
